# %%
import pandas as pd

# %%
df = pd.read_csv('Data/survey_results_public.csv')
schema_df = pd.read_csv('Data/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 79)
pd.set_option('display.max_rows', 79)

# %%
df.head(5)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
# Over the top, the tabular data can also be represented as a dictionary with columns as keys and lists as values
people = {
    "fname" : ["Anubhav", "Saksham"],
    "lname" : ["Sharma", "Sharma"]
}
people_df = pd.DataFrame(people)
people_df
# Out:
#      fname   lname
# 0  Anubhav  Sharma
# 1  Saksham  Sharma

# %%
#if you access the column through a dictionary, the data is of list type.
#if you access a column of a df then it is a series
print(type(people["fname"]))
print(type(people_df["fname"]))
# Out:
# <class 'list'>
# <class 'pandas.core.series.Series'>

# %%
# the column is a series
df['Employment']
# Out:
# 0                                                      NaN
# 1                                      Employed, full-time
# 2                                      Employed, full-time
# 3                                      Employed, full-time
# 4                                      Employed, full-time
#                                ...
# 73263                                  Employed, full-time
# 73264                                  Employed, full-time
# 73265                                  Employed, full-time
# 73266                                  Employed, full-time
# 73267    Independent contractor, freelancer, or self-em...
# Name: Employment, Length: 73268, dtype: object

# %%
# The columns are not a list but a series type
type(df['Employment'])
# Out:
# pandas.core.series.Series

# %%
# get column names
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
# Access multiple columns by passing a list
df[["MainBranch", "Employment", "RemoteWork"]].head(3)
# keep in mind that now the result is a data frame (subset) not a series. series is 1-D
# Out:
#                                           MainBranch           Employment  \
# 0                                      None of these                  NaN
# 1                     I am a developer by profession  Employed, full-time
# 2  I am not primarily a developer, but I write co...  Employed, full-time
#
#                              RemoteWork
# 0                                   NaN
# 1                          Fully remote
# 2  Hybrid (some remote, some in-person)

# %%
#iloc and loc use 2 arguments inside [] for rows and columns 
df.iloc[ [0,1], [0,1,2] ]
# Out:
#    ResponseId                      MainBranch           Employment
# 0           1                   None of these                  NaN
# 1           2  I am a developer by profession  Employed, full-time

# %%
df.loc[ [0,1], ["MainBranch", "Employment"] ]
# Out:
#                        MainBranch           Employment
# 0                   None of these                  NaN
# 1  I am a developer by profession  Employed, full-time

# %%
# you can also use range using ":" This is called SLICING
# This is called SLICING
df.iloc[1:4, 2:4]
# Out:
#             Employment                            RemoteWork
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote

# %%
#direct access from idex only takes one argument and that is only for rows
df[1:5]
# Out:
#    ResponseId                                         MainBranch  \
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# 3              I don’t code outside of work
# 4                                     Hobby
#
#                                            EdLevel  \
# ...

# %%
df.shape
# Out:
# (73268, 79)

# %%
# get frequency of items in the column
df["MainBranch"].value_counts()
# Out:
# MainBranch
# I am a developer by profession                                                   53507
# I am learning to code                                                             6309
# I am not primarily a developer, but I write code sometimes as part of my work     5794
# I code primarily as a hobby                                                       4865
# None of these                                                                     1497
# I used to be a developer by profession, but no longer am                          1296
# Name: count, dtype: int64

# %%
#info for first response
df.loc[0]
# Out:
# ResponseId                                    1
# MainBranch                        None of these
# Employment                                  NaN
# RemoteWork                                  NaN
# CodingActivities                            NaN
# EdLevel                                     NaN
# LearnCode                                   NaN
# LearnCodeOnline                             NaN
# LearnCodeCoursesCert                        NaN
# YearsCode                                   NaN
# YearsCodePro                                NaN
# DevType                                     NaN
# OrgSize                                     NaN
# PurchaseInfluence                           NaN
# BuyNewTool                                  NaN
# Country                                     NaN
# Currency                                    NaN
# CompTotal                                   NaN
# CompFreq                                    NaN
# LanguageHaveWorkedWith                      NaN
# ...

# %%
#info for a responseID and a particular question
df.loc[0, "RemoteWork"]
# Out:
# nan

# %%
# Sidenote Lists are sliceable
List = [1,2,3,4,5,6,7,8]
List[2:4]
# Out:
# [3, 4]

# %%
#Slicing and Inclusivity
df.iloc[0:1, 0:2]
#this does not look to be inclusive
# Out:
#    ResponseId     MainBranch
# 0           1  None of these

# %%
df[0:2]
# Still not inclusive
# Out:
#    ResponseId                      MainBranch           Employment  \
# 0           1                   None of these                  NaN
# 1           2  I am a developer by profession  Employed, full-time
#
#      RemoteWork                          CodingActivities EdLevel LearnCode  \
# 0           NaN                                       NaN     NaN       NaN
# 1  Fully remote  Hobby;Contribute to open-source projects     NaN       NaN
#
#   LearnCodeOnline LearnCodeCoursesCert YearsCode YearsCodePro DevType OrgSize  \
# 0             NaN                  NaN       NaN          NaN     NaN     NaN
# 1             NaN                  NaN       NaN          NaN     NaN     NaN
#
#   PurchaseInfluence BuyNewTool Country              Currency  CompTotal  \
# 0               NaN        NaN     NaN                   NaN        NaN
# 1               NaN        NaN  Canada  CAD\tCanadian dollar        NaN
#
#   CompFreq LanguageHaveWorkedWith LanguageWantToWorkWith  \
# ...

# %%
df.loc[0:2, "MainBranch"]
#This is inclusive
# Out:
# 0                                        None of these
# 1                       I am a developer by profession
# 2    I am not primarily a developer, but I write co...
# Name: MainBranch, dtype: object

# %%
## SO BASICALLY when using df.LOC slicing in INCLUSIVE but not when using index like df.ILOC
