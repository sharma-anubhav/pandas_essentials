# %%
import pandas as pd

# %%
# we are specifying the response ID as the index while loading the data itself. We can use the set_index method later on as well as shown below
df = pd.read_csv('Data/survey_results_public.csv', index_col = "ResponseId")
schema_df = pd.read_csv('Data/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 79)
pd.set_option('display.max_rows', 79)

# %%
df.head(5)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# ...

# %%
#lets go back to creating a simple data frame to understand indexing
# Over the top, the tabular data can also be represented as a dictionary with columns as keys and lists as values
people = {
    "fname" : ["Anubhav", "Saksham"],
    "lname" : ["Sharma", "Sharma"],
    "email" : ["anubhav@gmail.com", "saksham@gmail.com"]
}
people_df = pd.DataFrame(people)
people_df
# Out:
#      fname   lname              email
# 0  Anubhav  Sharma  anubhav@gmail.com
# 1  Saksham  Sharma  saksham@gmail.com

# %%
#pandas does not do many operations inplate if not specified. 
people_df.set_index("email")
#this is not inplace. df remains the same
# Out:
#                      fname   lname
# email
# anubhav@gmail.com  Anubhav  Sharma
# saksham@gmail.com  Saksham  Sharma

# %%
people_df.set_index("email", inplace = True)
people_df
# Out:
#                      fname   lname
# email
# anubhav@gmail.com  Anubhav  Sharma
# saksham@gmail.com  Saksham  Sharma

# %%
#specially useful if i want to get info for an entry
people_df.loc[["anubhav@gmail.com"]]
# Out:
#                      fname   lname
# email
# anubhav@gmail.com  Anubhav  Sharma

# %%
people_df.iloc[[0,1], :]
# Out:
#                      fname   lname
# email
# anubhav@gmail.com  Anubhav  Sharma
# saksham@gmail.com  Saksham  Sharma

# %%
df.index
# Out:
# RangeIndex(start=0, stop=73268, step=1)

# %%
people_df.index
# Out:
# Index(['anubhav@gmail.com', 'saksham@gmail.com'], dtype='object', name='email')

# %%
people_df.reset_index(inplace = True)
people_df
# Out:
#    index              email    fname   lname
# 0      0  anubhav@gmail.com  Anubhav  Sharma
# 1      1  saksham@gmail.com  Saksham  Sharma

# %%
schema_df.head(5)
# Out:
#       qid       qname                                           question  \
# 0   QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12    MetaInfo                                  Browser Meta Info
# 2    QID1          S1  <span style="font-size:22px; font-family: aria...
# 3    QID2  MainBranch  Which of the following options best describes ...
# 4  QID296  Employment  Which of the following best describes your cur...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    MC     MAVR

# %%
df.head(5)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# ...

# %%
#now if i want to get the question text(schema) from a question name(survey) i cannot without using filters
#but if i make the qname as the index in schema. I can directly access the qname information including what the questions was
schema_df.set_index("qname", inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/jq/lb5rtdpn7l1dzmj2h66pnbv40000gn/T/ipykernel_79787/2862413216.py in ?()
#       1 #now if i want to get the question text(schema) from a question name(survey) i cannot without using filters
#       2 #but if i make the qname as the index in schema. I can directly access the qname information including what the questions was
# ----> 3 schema_df.set_index("qname", inplace = True)
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6105                     if not found:
#    6106                         missing.append(col)
#    6107
#    6108         if missing:
# -> 6109             raise KeyError(f"None of {missing} are in the columns")
#    6110
#    6111         if inplace:
# ...

# %%
schema_df.loc["MainBranch", "question"]
# Out:
# 'Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code." <b>*</b>'

# %%
schema_df.sort_index(ascending = False, inplace = True)
schema_df
# Out:
#                          qid  \
# qname
# YearsCodePro           QID34
# YearsCode              QID32
# WorkExp               QID288
# Webframe              QID264
# VersionControlSystem  QID283
# VCInteraction         QID284
# VCHosting             QID285
# TrueFalse_3           QID294
# TrueFalse_2           QID294
# TrueFalse_1           QID294
# TrueFalse             QID294
# Trans                 QID153
# ToolsTech             QID275
# TimeSearching         QID291
# TimeAnswering         QID292
# TBranch               QID299
# SurveyLength          QID132
# SurveyEase            QID133
# Sexuality             QID136
# SOVisitFreq           QID100
# SOTeamsUsage          QID286
# SOPartFreq            QID102
# SOComm                QID106
# SOAccount             QID101
# S7                    QID131
# S6                    QID295
# S5                    QID121
# S4                     QID91
# S3                     QID61
# S2                    QID190
# ...
